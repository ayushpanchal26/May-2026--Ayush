# %%
def optimal(arr1, arr2):
    n = len(arr1)
    m = len(arr2)
    union = []

    i, j = 0, 0 

    while i<n and j<m:
        if arr1[i] <arr2[j]:
            if not union or union[-1] != arr1[i]:
                union.append(arr1[i])
            i+=1

        elif arr2
