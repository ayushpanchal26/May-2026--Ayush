# %% [markdown]
# Brute

# %%
def mybrute(arr, k):
    n = len(arr)
    temp = [0] * k

    for i in range(0, k):
        temp[i] = arr[i]

    for i in range(k ,n):
        arr[i - k] = arr[i]

    for i in range

    
    return arr

arr = [1,2,3,4,5]

mybrute(arr, 2)
# Out:
# [3, 4, 5, 4, 5]

# %%
def brute_rotate_right(arr):
    n = len(arr)
    if n == 0:
        return
    
    k %= n

    temp = arr[-k:]

    for i in range(n - k - 1, -1, -1):
        arr[i + k] = arr[i]

    for i in range(k):
        arr[i] = temp[i]


def brute_rotate_left(arr):
    n = len(arr)
    if n == 0:
        return
    
    k %= 0

    temp = arr[:k]

    for i in range(k, n):
        arr[i-k] = arr[i]

    for i in range(k):
        arr[n-k+i] = temp[i]

# %%
def brute_rotate_left(arr, k):
    n = len(arr)
    if n == 0:
        return
    
    k %= n

    temp = arr[:k]

    for i in range(k, n):
        arr[i - k] = arr[i]

    for i in range(k):
        arr[n-k+i] = temp[i]
    return arr

arr = [1,2,3,4,5]

brute_rotate_left(arr, 1)
# Out:
# [2, 3, 4, 5, 1]

# %%
arr = [1,2,3,4,5]
k = 2
temp = arr[-k:]
print(temp)
n = len(arr)
print(n)
# Out:
# [4, 5]
# 5

# %%
def rightRotates(arr, k):
    n = len(arr)
    if n == 0:
        return
    
    k %= n

    temp = arr[-k:]

    for i in range(n - k - 1, -1, -1):
        arr[i+k] = arr[i]

    for i in range(k):
        arr[i] = temp[i]


    return arr

def rightLefts(arr, k):
    n = len(arr)
    if n == 0:
        return
    
    k %= n

    temp = arr[:k]

    for i in range(k, n):
        arr[i-k] = arr[i]

    for i in range(k):
        arr[n-k+i] = temp[i]

    return arr

arr = [1,2,3,4,5]
k = 2

print(rightRotates(arr, 1))
print(rightLefts(arr, 1))
# Out:
# [5, 1, 2, 3, 4]
# [1, 2, 3, 4, 5]
